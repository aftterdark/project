# %%
# Подключаем библиотеки
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import BatchNormalization
import numpy as np
import matplotlib.pyplot as plt

# Загружаем датасет MNIST
(x_train, y_train), (x_val, y_val) = tf.keras.datasets.mnist.load_data()

# Нормализация изображений
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0

# Добавляем измерение канала (делаем изображения 28x28x1)
x_train = np.expand_dims(x_train, axis=-1)
x_val = np.expand_dims(x_val, axis=-1)

# Преобразуем метки в one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_val = tf.keras.utils.to_categorical(y_val, 10)

# Размер изображений
IMG_SIZE = 28  # Для MNIST размер 28x28

# Улучшенная модель (похожа на твою)
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')  # 10 классов (0-9)
])

# Компиляция модели
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks для уменьшения переобучения
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)

# Обучение модели
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=10,  # Можно увеличить
    batch_size=32,
    callbacks=[reduce_lr]
)

# Сохранение модели
model.save('mnist_model.keras')

# Графики обучения
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 100s 50ms/step - accuracy: 0.8826 - loss: 0.3900 - val_accuracy: 0.9707 - val_loss: 0.0977 - learning_rate: 0.0010
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 138s 48ms/step - accuracy: 0.9764 - loss: 0.0793 - val_accuracy: 0.9782 - val_loss: 0.0775 - learning_rate: 0.0010
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 142s 48ms/step - accuracy: 0.9812 - loss: 0.0594 - val_accuracy: 0.9846 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 89s 47ms/step - accuracy: 0.9846 - loss: 0.0498 - val_accuracy: 0.9842 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9873 - loss: 0.0406
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 142s 47ms/step - accuracy: 0.9873 - loss: 0.0406 - val_accuracy: 0.9844 - val_loss: 0.0525 - learning_rate: 0.0010
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 142s 47ms/step - accuracy: 0.9911 - loss: 0.0279 - val_accuracy: 0.9895 - val_loss: 0.0380 - learning_rate: 5.0000e-04
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 146s 49ms/step - accuracy: 0.9940 - loss: 0.0185 - val_accuracy: 0.9898 - val_loss: 0.0380 - learning_rate: 5.0000e-04
# Epoch 8/10
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9955 - loss: 0.0150
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 138s 47ms/step - accuracy: 0.9955 - loss: 0.0150 - val_accuracy: 0.9897 - val_loss: 0.0444 - learning_rate: 5.0000e-04
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 89s 47ms/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.9910 - val_loss: 0.0342 - learning_rate: 2.5000e-04
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 143s 48ms/step - accuracy: 0.9974 - loss: 0.0085 - val_accuracy: 0.9908 - val_loss: 0.0378 - learning_rate: 2.5000e-04
